# %% [markdown]
# ### strings

# %%
s = "hello aditya"
s.split()
# Out:
# ['hello', 'aditya']

# %%
s.count("l")
# Out:
# 2

# %%
u="ADITYA"
u.isupper()
# Out:
# True

# %%
u="ADITYA"
u.lower()
# Out:
# 'aditya'

# %%
u="ADiTya"
u.swapcase()
# Out:
# 'adItYA'

# %%
s = "hello aditya"
len(s)
# Out:
# 12

# %%
t = "aditya college"
t.title()

# %%
dir(str)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
#  'rpartition',
#  'rsplit',
#  'rstrip',
#  'split',
#  'splitlines',
#  'startswith',
#  'strip',
#  'swapcase',
#  'title',
#  'translate',
#  'upper',
#  'zfill']

# %%
s = "   aditya     "
s.lstrip()
s.rstrip()
# Out:
# '   aditya'

# %%
s = "python workshop"
s.startswith("p")
s.endswith("p")
s.replace("workshop","programming")
# Out:
# 'python programming'

# %%
s="aditya456"
s.isalpha()
s.isnumeric()
s.isalnum()
# Out:
# True

# %%
s="aditya12college45python67"
sum1=0
for i in s:
    if i.isdigit():
        sum1+=int(i)
         print(sum1)
# Out:
#   File "<ipython-input-14-b38729e32e02>", line 6
#     print(sum1)
#     ^
# IndentationError: unexpected indent

# %%
s="aditya"
s.index("a",2)
# Out:
# 5

# %%
s=input("Enter Input")
count=0
m=0
n=0
for i in s:
    if i.isdigit():
        count+=1
    elif i.isalpha():
        m+=1
    elif i.isspace():
        n+=1
print(count,m,n)
# Out:
# Enter Inputabc 1 23
# 3 3 2

# %%
n=input("enter string")
s=input("enter new string")
a=len(n)
b=a//2
print(n[:b]+s+n[b:])
# Out:
# enter stringhiiii
# enter new stringa
# hiaiii
